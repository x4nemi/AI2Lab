# %% [markdown]
# # Regresión Lineal Univariable con `sklearn`

# %% [markdown]
# ### Datos de entrada

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

data = pd.read_csv('dataset_RegresionLineal.csv')
x = np.array(data['x'])
y = np.array(data['y'])

plt.plot(x, y, 'o', color="magenta", mec="black")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Modelo de regresión lineal univariable por sklearn

# %%
model = linear_model.LinearRegression()
model.fit(x.reshape(-1, 1), y)

h = model.predict(x.reshape(-1, 1))
plt.plot(x, y, 'o', color="magenta", mec="black")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, h, color="blue")
print('a0:', model.intercept_, 'a1:', model.coef_[0])
# Out:
# a0: -3.8957808783118484 a1: 1.1930336441895932

# %% [markdown]
# ### Evaluación del modelo con un dato de prueba

# %%
datoPrueba = 5.62
prediccion = model.predict([[datoPrueba]])
print('Prediccion para x =', datoPrueba, 'es', prediccion[0])

plt.plot(x, y, 'o', color="magenta", mec="black")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, h, color="blue")
plt.plot(datoPrueba, prediccion, 'o', mec = "black", color="yellow", markersize=10)
# Out:
# Prediccion para x = 5.62 es 2.809068202033666
